# %% [markdown]
# <a href="https://colab.research.google.com/github/LukasSchmauch/bin_packing_problem/blob/main/Results.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Alle Versuche ohne festen SEED (teilweise sind Feasibility Tets und Assertions enthalten --> langsamere Laufzeit), zudem sind die "ersten Versuche" noch nicht mit dem aktuellsten Skript

# %% [markdown]
# # ohne 2:1 Move

# %% [markdown]
# # 30 Iterationen (Uniform)

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/LukasSchmauch/bin_packing_problem/main/Results/results_unif_30.csv'
df = pd.read_csv(url)
df_grouped = df.groupby(['Typ', 'Anzahl Items'])
df_mean = df_grouped.mean()
df_mean.columns = ['Bin-Kapazitaet', ' Mean LB', 'Mean Hill Climbing', 'Mean First Fit Descending','Mean Abs. LB HC', 'Mean Abs. LB FFD', 'Mean Zeit HC (sec)', 'Mean Zeit FFD (sec)']
df_mean
# Out:
#                       Bin-Kapazitaet  ...  Mean Zeit FFD (sec)
# Typ     Anzahl Items                  ...
# uniform 120                    150.0  ...               0.0030
#         250                    150.0  ...               0.0175
#         500                    150.0  ...               0.0650
#         1000                   150.0  ...               0.2660
#
# [4 rows x 8 columns]

# %% [markdown]
# # 100 Iterationen (Unif und Trip)

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/LukasSchmauch/bin_packing_problem/main/Results/results_unif_triplet_100.csv'
df = pd.read_csv(url)
df_grouped = df.groupby(['Typ', 'Anzahl Items'])
df_mean = df_grouped.mean()
df_mean.columns = ['Bin-Kapazitaet', ' Mean LB', 'Mean Hill Climbing', 'Mean First Fit Descending','Mean Abs. LB HC', 'Mean Abs. LB FFD', 'Mean Zeit HC (sec)', 'Mean Zeit FFD (sec)']
df_mean
# Out:
#                       Bin-Kapazitaet  ...  Mean Zeit FFD (sec)
# Typ     Anzahl Items                  ...
# triplet 60                    1000.0  ...               0.0000
#         120                   1000.0  ...               0.0005
#         249                   1000.0  ...               0.0105
#         501                   1000.0  ...               0.0510
# uniform 120                    150.0  ...               0.0010
#         250                    150.0  ...               0.0105
#         500                    150.0  ...               0.0525
#         1000                   150.0  ...               0.2280
#
# [8 rows x 8 columns]

# %% [markdown]
# # 300 Iterationen (Trip. 501 Items)

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/LukasSchmauch/bin_packing_problem/main/Results/results_triplet_300.csv'
df = pd.read_csv(url)
df_grouped = df.groupby(['Typ', 'Anzahl Items'])
df_mean = df_grouped.mean()
df_mean.columns = ['Bin-Kapazitaet', ' Mean LB', 'Mean Hill Climbing', 'Mean First Fit Descending','Mean Abs. LB HC', 'Mean Abs. LB FFD', 'Mean Zeit HC (sec)', 'Mean Zeit FFD (sec)']
df_mean
# Out:
#                       Bin-Kapazitaet  ...  Mean Zeit FFD (sec)
# Typ     Anzahl Items                  ...
# triplet 501                   1000.0  ...                0.075
#
# [1 rows x 8 columns]

# %% [markdown]
# # Ab hier zuzüglich 2:1 Move

# %% [markdown]
# #30 Iterationen Uniform und Triplet

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/LukasSchmauch/bin_packing_problem/main/Results/results_30_beide.csv'
df = pd.read_csv(url)
df_grouped = df.groupby(['Typ', 'Anzahl Items'])
df_mean = df_grouped.mean()
df_mean.columns = ['Bin-Kapazitaet', ' Mean LB', 'Mean Hill Climbing', 'Mean First Fit Descending','Mean Abs. LB HC', 'Mean Abs. LB FFD', 'Mean Zeit HC (sec)', 'Mean Zeit FFD (sec)']
df_mean
# Out:
#                       Bin-Kapazitaet  ...  Mean Zeit FFD (sec)
# Typ     Anzahl Items                  ...
# triplet 60                    1000.0  ...               0.0000
#         120                   1000.0  ...               0.0005
#         249                   1000.0  ...               0.0135
#         501                   1000.0  ...               0.0560
# uniform 120                    150.0  ...               0.0010
#         250                    150.0  ...               0.0170
#         500                    150.0  ...               0.0660
#         1000                   150.0  ...               0.2950
#
# [8 rows x 8 columns]

# %% [markdown]
# # 50 Iters uniform und triplet

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/LukasSchmauch/bin_packing_problem/main/Results/results_triplet_50iters_mit_move21.csv'
df = pd.read_csv(url)
df_grouped = df.groupby(['Typ', 'Anzahl Items'])
df_mean = df_grouped.mean()
df_mean.columns = ['Bin-Kapazitaet', ' Mean LB', 'Mean Hill Climbing', 'Mean First Fit Descending','Mean Abs. LB HC', 'Mean Abs. LB FFD', 'Mean Zeit HC (sec)', 'Mean Zeit FFD (sec)']
df_mean
# Out:
#                       Bin-Kapazitaet  ...  Mean Zeit FFD (sec)
# Typ     Anzahl Items                  ...
# triplet 60                    1000.0  ...               0.0000
#         120                   1000.0  ...               0.0000
#         249                   1000.0  ...               0.0125
#         501                   1000.0  ...               0.0555
# uniform 120                    150.0  ...               0.0035
#         250                    150.0  ...               0.0240
#         500                    150.0  ...               0.0705
#         1000                   150.0  ...               0.3265
#
# [8 rows x 8 columns]

# %% [markdown]
# # 100 Iterationen Unif Triplet

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/LukasSchmauch/bin_packing_problem/main/Results/results_triplet_100iters_mit_move21.csv'
df = pd.read_csv(url)
df_grouped = df.groupby(['Typ', 'Anzahl Items'])
df_mean = df_grouped.mean()
df_mean.columns = ['Bin-Kapazitaet', ' Mean LB', 'Mean Hill Climbing', 'Mean First Fit Descending','Mean Abs. LB HC', 'Mean Abs. LB FFD', 'Mean Zeit HC (sec)', 'Mean Zeit FFD (sec)']
df_mean
# Out:
#                       Bin-Kapazitaet  ...  Mean Zeit FFD (sec)
# Typ     Anzahl Items                  ...
# triplet 60                    1000.0  ...               0.0000
#         120                   1000.0  ...               0.0000
#         249                   1000.0  ...               0.0105
#         501                   1000.0  ...               0.0500
# uniform 120                    150.0  ...               0.0015
#         250                    150.0  ...               0.0105
#         500                    150.0  ...               0.0530
#         1000                   150.0  ...               0.2255
#
# [8 rows x 8 columns]

# %% [markdown]
# # 300 Iteration Triplet 501

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/LukasSchmauch/bin_packing_problem/main/Results/results_triplet_300iters_mit_move21.csv'
df = pd.read_csv(url)
df_grouped = df.groupby(['Typ', 'Anzahl Items'])
df_mean = df_grouped.mean()
df_mean.columns = ['Bin-Kapazitaet', ' Mean LB', 'Mean Hill Climbing', 'Mean First Fit Descending','Mean Abs. LB HC', 'Mean Abs. LB FFD', 'Mean Zeit HC (sec)', 'Mean Zeit FFD (sec)']
df_mean
# Out:
#                       Bin-Kapazitaet  ...  Mean Zeit FFD (sec)
# Typ     Anzahl Items                  ...
# triplet 501                   1000.0  ...                0.065
#
# [1 rows x 8 columns]

# %% [markdown]
# # 500 Iterationen Unif und Triplet

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/LukasSchmauch/bin_packing_problem/main/Results/results_500_unif_trip.csv'
df = pd.read_csv(url)
df_grouped = df.groupby(['Typ', 'Anzahl Items'])
df_mean = df_grouped.mean()
df_mean.columns = ['Bin-Kapazitaet', ' Mean LB', 'Mean Hill Climbing', 'Mean First Fit Descending','Mean Abs. LB HC', 'Mean Abs. LB FFD', 'Mean Zeit HC (sec)', 'Mean Zeit FFD (sec)']
df_mean
# Out:
#                       Bin-Kapazitaet  ...  Mean Zeit FFD (sec)
# Typ     Anzahl Items                  ...
# triplet 60                    1000.0  ...               0.0000
#         120                   1000.0  ...               0.0015
#         249                   1000.0  ...               0.0225
#         501                   1000.0  ...               0.0855
# uniform 120                    150.0  ...               0.0025
#         250                    150.0  ...               0.0210
#         500                    150.0  ...               0.0905
#         1000                   150.0  ...               0.3735
#
# [8 rows x 8 columns]

# %% [markdown]
# # Ab hier mit korrigierten Skript

# %% [markdown]
# # 500 Iterationen

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/LukasSchmauch/bin_packing_problem/main/results_neu/results_500_neu.csv'
df = pd.read_csv(url)
df_grouped = df.groupby(['Typ', 'Anzahl Items'])
df_mean = df_grouped.mean()
df_mean.columns = ['Bin-Kapazitaet', ' Mean LB', 'Mean Hill Climbing', 'Mean First Fit Descending','Mean Abs. LB HC', 'Mean Abs. LB FFD', 'Mean Zeit HC (sec)', 'Mean Zeit FFD (sec)']
df_mean
# Out:
#                       Bin-Kapazitaet  ...  Mean Zeit FFD (sec)
# Typ     Anzahl Items                  ...
# triplet 60                    1000.0  ...               0.0000
#         120                   1000.0  ...               0.0000
#         249                   1000.0  ...               0.0100
#         501                   1000.0  ...               0.0535
# uniform 120                    150.0  ...               0.0025
#         250                    150.0  ...               0.0205
#         500                    150.0  ...               0.0990
#         1000                   150.0  ...               0.4385
#
# [8 rows x 8 columns]

# %% [markdown]
# # Verbesserung pro Iteration 501 Triplet Instanzen

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
url = 'https://raw.githubusercontent.com/LukasSchmauch/bin_packing_problem/main/Results/results_501_Itermessung1000.csv'
df = pd.read_csv(url)
grouped_df = df.groupby('Iteration').mean()
grouped_df.columns = ['Instanzindex', 'Anz_Items','Bin_Size','LB','HC-LB']

plt.figure(figsize=(14,10))
sns.lineplot(data=grouped_df["HC-LB"], label= 'Abweichung LB')
plt.title('Durchschnittliche Abweichung der HC Lösung von LB pro Iteration', fontsize = 20)
plt.xlabel('Anzahl Iterationen', fontsize = 15)
plt.ylabel('Zusätzliche Bins ggü. LB', fontsize = 15)
plt.yticks(np.arange(0, 24, 1))
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.hlines(1,0,1000, colors='red', linestyles='solid', label = 'Abweichung = 1')
plt.legend()

# %% [markdown]
# # 30 Iterationen mit Wahl der Permutation nach Heuristik (Minimale Itemzahl) --> Deterministisch

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/LukasSchmauch/bin_packing_problem/main/Results/results_30_minimum.csv'
df = pd.read_csv(url)
df_grouped = df.groupby(['Typ', 'Anzahl Items'])
df_mean = df_grouped.mean()
df_mean.columns = ['Bin-Kapazitaet', ' Mean LB', 'Mean Hill Climbing', 'Mean First Fit Descending','Mean Abs. LB HC', 'Mean Abs. LB FFD', 'Mean Zeit HC (sec)', 'Mean Zeit FFD (sec)']
df_mean
# Out:
#                       Bin-Kapazitaet  ...  Mean Zeit FFD (sec)
# Typ     Anzahl Items                  ...
# triplet 60                    1000.0  ...               0.0000
#         120                   1000.0  ...               0.0015
#         249                   1000.0  ...               0.0170
#         501                   1000.0  ...               0.0675
# uniform 120                    150.0  ...               0.0015
#         250                    150.0  ...               0.0145
#         500                    150.0  ...               0.0695
#         1000                   150.0  ...               0.2935
#
# [8 rows x 8 columns]
